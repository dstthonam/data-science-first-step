# %%
import pandas as pd

# gapmider = pd.read_csv("인터넷 주소, ~tsv", sep ='\t')

gapminder = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/데이터 과학/파이썬으로_시작하는_데이터_과학_첫걸음/gapminder.csv")
type(gapminder)
# Out:
# pandas.core.frame.DataFrame

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
print(gapminder.head(10))
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106
# 5  Afghanistan      Asia  1977   38.438  14880372  786.113360
# 6  Afghanistan      Asia  1982   39.854  12881816  978.011439
# 7  Afghanistan      Asia  1987   40.822  13867957  852.395945
# 8  Afghanistan      Asia  1992   41.674  16317921  649.341395
# 9  Afghanistan      Asia  1997   41.763  22227415  635.341351

# %%
print(gapminder.tail(10))
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 1694  Zimbabwe    Africa  1962   52.358   4277736  527.272182
# 1695  Zimbabwe    Africa  1967   53.995   4995432  569.795071
# 1696  Zimbabwe    Africa  1972   55.635   5861135  799.362176
# 1697  Zimbabwe    Africa  1977   57.674   6642107  685.587682
# 1698  Zimbabwe    Africa  1982   60.363   7636524  788.855041
# 1699  Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700  Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701  Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702  Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703  Zimbabwe    Africa  2007   43.487  12311143  469.709298

# %%
gapminder.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1704 non-null   object
#  1   continent  1704 non-null   object
#  2   year       1704 non-null   int64
#  3   lifeExp    1704 non-null   float64
#  4   pop        1704 non-null   int64
#  5   gdpPercap  1704 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB

# %%
gapminder.describe()
# Out:
#              year      lifeExp           pop      gdpPercap
# count  1704.00000  1704.000000  1.704000e+03    1704.000000
# mean   1979.50000    59.474439  2.960121e+07    7215.327081
# std      17.26533    12.917107  1.061579e+08    9857.454543
# min    1952.00000    23.599000  6.001100e+04     241.165876
# 25%    1965.75000    48.198000  2.793664e+06    1202.060309
# 50%    1979.50000    60.712500  7.023596e+06    3531.846988
# 75%    1993.25000    70.845500  1.958522e+07    9325.462346
# max    2007.00000    82.603000  1.318683e+09  113523.132900

# %%
gapminder['year'].unique()
# Out:
# array([1952, 1957, 1962, 1967, 1972, 1977, 1982, 1987, 1992, 1997, 2002,
#        2007])

# %%
gapminder['country'].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Argentina',
#        'Australia', 'Austria', 'Bahrain', 'Bangladesh', 'Belgium',
#        'Benin', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon',
#        'Canada', 'Central African Republic', 'Chad', 'Chile', 'China',
#        'Colombia', 'Comoros', 'Congo, Dem. Rep.', 'Congo, Rep.',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Czech Republic',
#        'Denmark', 'Djibouti', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Ethiopia',
#        'Finland', 'France', 'Gabon', 'Gambia', 'Germany', 'Ghana',
#        'Greece', 'Guatemala', 'Guinea', 'Guinea-Bissau', 'Haiti',
#        'Honduras', 'Hong Kong, China', 'Hungary', 'Iceland', 'India',
#        'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Israel', 'Italy',
#        'Jamaica', 'Japan', 'Jordan', 'Kenya', 'Korea, Dem. Rep.',
# ...

# %%
gapminder['continent'].unique()
# Out:
# array(['Asia', 'Europe', 'Africa', 'Americas', 'Oceania'], dtype=object)

# %%
gapminder['year'].value_counts()
# Out:
# 1952    142
# 1957    142
# 1962    142
# 1967    142
# 1972    142
# 1977    142
# 1982    142
# 1987    142
# 1992    142
# 1997    142
# 2002    142
# 2007    142
# Name: year, dtype: int64

# %%
gapminder['country'].value_counts()
# Out:
# Afghanistan          12
# Pakistan             12
# New Zealand          12
# Nicaragua            12
# Niger                12
#                      ..
# Eritrea              12
# Equatorial Guinea    12
# El Salvador          12
# Egypt                12
# Zimbabwe             12
# Name: country, Length: 142, dtype: int64

# %%
gapminder['continent'].value_counts()
# Out:
# Africa      624
# Asia        396
# Europe      360
# Americas    300
# Oceania      24
# Name: continent, dtype: int64

# %%
print(gapminder.max())
print('\n')

print(gapminder['lifeExp']. max())
print('\n')

print(gapminder['country']. max())
# Out:
# country         Zimbabwe
# continent        Oceania
# year                2007
# lifeExp           82.603
# pop           1318683096
# gdpPercap    113523.1329
# dtype: object
#
#
# 82.603
#
#
# Zimbabwe

# %%
print(gapminder.min())
print('\n')

print(gapminder['lifeExp'].min())
print('\n')

print(gapminder['country'].min())
# Out:
# country      Afghanistan
# continent         Africa
# year                1952
# lifeExp           23.599
# pop                60011
# gdpPercap     241.165876
# dtype: object
#
#
# 23.599
#
#
# Afghanistan

# %%
print(gapminder.median())
print('\n')

print(gapminder['lifeExp'].median())
# Out:
# year         1.979500e+03
# lifeExp      5.947444e+01
# pop          2.960121e+07
# gdpPercap    7.215327e+03
# dtype: float64
#
#
# 59.474439366197174
# <ipython-input-38-0aec63236ab5>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print(gapminder.mean())

# %%
print(gapminder.mean())
print('\n')

print(gapminder['lifeExp'].mean())
# Out:
# year         1.979500e+03
# lifeExp      6.071250e+01
# pop          7.023596e+06
# gdpPercap    3.531847e+03
# dtype: float64
#
#
# 60.7125
# <ipython-input-39-9c04cb76fc6e>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print(gapminder.median())

# %%
print(gapminder.std())
print('\n')

print(gapminder['lifeExp'].std())
# Out:
# year         1.726533e+01
# lifeExp      1.291711e+01
# pop          1.061579e+08
# gdpPercap    9.857455e+03
# dtype: float64
#
#
# 12.917107415241192
# <ipython-input-40-7362345d7530>:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print(gapminder.std())

# %%
print(gapminder.corr())
print('\n')

print(gapminder[['lifeExp', 'year']].corr())
# Out:
#                year   lifeExp       pop  gdpPercap
# year       1.000000  0.435611  0.082308   0.227318
# lifeExp    0.435611  1.000000  0.064955   0.583706
# pop        0.082308  0.064955  1.000000  -0.025600
# gdpPercap  0.227318  0.583706 -0.025600   1.000000
#
#
#           lifeExp      year
# lifeExp  1.000000  0.435611
# year     0.435611  1.000000
# <ipython-input-43-3dc0bb099e68>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print(gapminder.corr())

# %%
finance = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/데이터 과학/파이썬으로_시작하는_데이터_과학_첫걸음/finance_xlsx.xlsx")
finance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   통화명     58 non-null     object
#  1   매매기준율   58 non-null     float64
#  2   현찰 살 때  36 non-null     float64
#  3   현찰 팔 때  36 non-null     float64
#  4   송금 보낼때  30 non-null     float64
#  5   송금 받을때  32 non-null     float64
#  6   미화 환산율  58 non-null     float64
# dtypes: float64(6), object(1)
# memory usage: 3.3+ KB

# %%
# finance.head(10).isnull()
finance.isnull().sum()
# Out:
# 통화명        0
# 매매기준율      0
# 현찰 살 때    22
# 현찰 팔 때    22
# 송금 보낼때    28
# 송금 받을때    26
# 미화 환산율     0
# dtype: int64

# %%
# finance.head(10).notnull()
finance.notnull().sum()
# Out:
# 통화명       58
# 매매기준율     58
# 현찰 살 때    36
# 현찰 팔 때    36
# 송금 보낼때    30
# 송금 받을때    32
# 미화 환산율    58
# dtype: int64

# %%
finance_dropna = finance.dropna(axis = 0)
finance_dropna.isnull().sum()
# Out:
# 통화명       0
# 매매기준율     0
# 현찰 살 때    0
# 현찰 팔 때    0
# 송금 보낼때    0
# 송금 받을때    0
# 미화 환산율    0
# dtype: int64

# %%
# 현찰 살 때의 NAN값을 buy의 값으로 변경하기

buy = finance['매매기준율'] * 1.02
buy = round(buy , 2)
finance['현찰 살 때'].fillna(buy, inplace = True)

print(finance['현찰 살 때'].isnull().sum())
finance.info()
# Out:
# 0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   통화명     58 non-null     object
#  1   매매기준율   58 non-null     float64
#  2   현찰 살 때  58 non-null     float64
#  3   현찰 팔 때  36 non-null     float64
#  4   송금 보낼때  30 non-null     float64
#  5   송금 받을때  32 non-null     float64
#  6   미화 환산율  58 non-null     float64
# dtypes: float64(6), object(1)
# memory usage: 3.3+ KB

# %%
import seaborn as sns
import pandas as pd

df = sns.load_dataset('titanic')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df1 = df.dropna(axis = 1, thresh = 500)

print(df1.isnull().sum())
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
age_mean = df['age'].mean()

df['age'].fillna(age_mean, inplace = True)
print(df['age'].isnull().sum())

print(df['embarked'].value_counts())
df['embarked'].fillna("S", inplace = True)
print(df['embarked'].isnull().sum())

embark_town = df['embark_town'].value_counts()
df['embark_town'].fillna("embark_town", inplace = True)
print(df['embark_town'].isnull().sum())

print(df.isnull().sum())
# Out:
# 0
# S    646
# C    168
# Q     77
# Name: embarked, dtype: int64
# 0
# 0
# survived         0
# pclass           0
# sex              0
# age              0
# sibsp            0
# parch            0
# fare             0
# embarked         0
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      0
# alive            0
# alone            0
# dtype: int64
